# %%
import os
import gym
import numpy as np
import tensorflow as tf

# Killing optional CPU driver warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

class Reinforce(tf.keras.Model):

    def __init__(self, state_size, num_actions):
        """
        The Reinforce class that inherits from tf.keras.Model
        The forward pass calculates the policy for the agent given a batch of states.

        """
        super(Reinforce, self).__init__()
        self.num_actions = num_actions

        # TODO: Define network parameters and optimizer

        self.optimizer = tf.optimizers.Adam()
        self.D1 = tf.keras.layers.Dense(32)
        self.D2 = tf.keras.layers.Dense(32)
        self.D3 = tf.keras.layers.Dense(num_actions)

    def call(self, states):
        """
        Performs the forward pass on a batch of states to generate the action probabilities.
        This returns a policy tensor of shape [episode_length, num_actions], where each row is a
        probability distribution over actions for each state.

        :param states: An [episode_length, state_size] dimensioned array
        representing the history of states of an episode
        :return: A [episode_length,num_actions] matrix representing the probability distribution over actions
        for each state in the episode
        """

        logits = self.D1(states)
        logits = self.D2(logits)
        logits = self.D3(logits)
        probs = tf.nn.softmax(logits)

        return probs

    def loss(self, states, actions, discounted_rewards):
        """
        Computes the loss for the agent. Make sure to understand the handout clearly when implementing this.

        :param states: A batch of states of shape [episode_length, state_size]
        :param actions: History of actions taken at each timestep of the episode (represented as an [episode_length] array)
        :param discounted_rewards: Discounted rewards throughout a complete episode (represented as an [episode_length] array)
        :return: loss, a Tensorflow scalar
        """

        probs = self.call(np.array(states))
        actions = tf.expand_dims(actions,1)

        logged = tf.math.log(tf.gather_nd(probs, actions, 1))

        return -tf.reduce_sum(logged * discounted_rewards)

class Reinforce2(tf.keras.Model):
    def __init__(self, state_size, num_actions):
        """
        The Reinforce class that inherits from tf.keras.Model
        The forward pass calculates the policy for the agent given a batch of states.
        :param num_actions: number of actions in an environment
        """
        super(Reinforce2, self).__init__()
        self.num_actions = num_actions


        self.optimizer = tf.optimizers.Adam()
        self.D1 = tf.keras.layers.Dense(32)
        self.D2 = tf.keras.layers.Dense(8)
        self.D3 = tf.keras.layers.Dense(num_actions)

    def call(self, states):
        """
        Performs the forward pass on a batch of states to generate the action probabilities.
        This returns a policy tensor of shape [episode_length, num_actions], where each row is a
        probability distribution over actions for each state.

        :param states: An [episode_length, state_size] dimensioned array
        representing the history of states of an episode
        :return: A [episode_length,num_actions] matrix representing the probability distribution over actions
        for each state in the episode
        """

        logits = self.D1(states)
        logits = self.D2(logits)
        logits = self.D3(logits)
        probs = tf.nn.softmax(logits)

        return probs

    def loss(self, states, actions, discounted_rewards):
        """
        Computes the loss for the agent. Make sure to understand the handout clearly when implementing this.

        :param states: A batch of states of shape [episode_length, state_size]
        :param actions: History of actions taken at each timestep of the episode (represented as an [episode_length] array)
        :param discounted_rewards: Discounted rewards throughout a complete episode (represented as an [episode_length] array)
        :return: loss, a Tensorflow scalar
        """

        probs = self.call(np.array(states))
        actions = tf.expand_dims(actions,1)

        logged = tf.math.log(tf.gather_nd(probs, actions, 1))

        return -tf.reduce_sum(logged * discounted_rewards)

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pypokerengine in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Started the round 1
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 198
# "p2" declared "call:2"
# SMALLSTACK/POT
# 4
# 198
# "p1" declared "call:2"
# Street "flop" started. (community card = ['SQ', 'SA', 'CK'])
# SMALLSTACK/POT
# 4
# 198
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 198
# "p1" declared "call:0"
# Street "turn" started. (community card = ['SQ', 'SA', 'CK', 'H3'])
# SMALLSTACK/POT
# 4
# 198
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 198
# "p1" declared "call:0"
# Street "river" started. (community card = ['SQ', 'SA', 'CK', 'H3', 'S3'])
# SMALLSTACK/POT
# 4
# 198
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 198
# "p1" declared "call:0"
# "['p2']" won the round 1 (stack = {'p1': 198, 'p2': 202})
# Started the round 2
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 197
# "p1" declared "call:2"
# SMALLSTACK/POT
# 4
# 196
# "p2" declared "call:2"
# Street "flop" started. (community card = ['CQ', 'C2', 'H4'])
# SMALLSTACK/POT
# 4
# 196
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 196
# "p2" declared "call:0"
# Street "turn" started. (community card = ['CQ', 'C2', 'H4', 'S9'])
# SMALLSTACK/POT
# 4
# 196
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 196
# "p2" declared "call:0"
# Street "river" started. (community card = ['CQ', 'C2', 'H4', 'S9', 'C7'])
# SMALLSTACK/POT
# 4
# 196
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 196
# "p2" declared "call:0"
# "['p2']" won the round 2 (stack = {'p1': 196, 'p2': 204})
# Started the round 3
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 194
# "p2" declared "call:2"
# SMALLSTACK/POT
# 4
# 194
# "p1" declared "call:2"
# Street "flop" started. (community card = ['HJ', 'C3', 'CT'])
# SMALLSTACK/POT
# 4
# 194
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 194
# "p1" declared "call:0"
# Street "turn" started. (community card = ['HJ', 'C3', 'CT', 'S5'])
# SMALLSTACK/POT
# 4
# 194
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 194
# "p1" declared "call:0"
# Street "river" started. (community card = ['HJ', 'C3', 'CT', 'S5', 'SK'])
# SMALLSTACK/POT
# 4
# 194
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 194
# "p1" declared "call:0"
# "['p2']" won the round 3 (stack = {'p1': 194, 'p2': 206})
# Started the round 4
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 193
# "p1" declared "call:2"
# SMALLSTACK/POT
# 4
# 192
# "p2" declared "call:2"
# Street "flop" started. (community card = ['C8', 'S9', 'DA'])
# SMALLSTACK/POT
# 4
# 192
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 192
# "p2" declared "call:0"
# Street "turn" started. (community card = ['C8', 'S9', 'DA', 'HK'])
# SMALLSTACK/POT
# 4
# 192
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 192
# "p2" declared "call:0"
# Street "river" started. (community card = ['C8', 'S9', 'DA', 'HK', 'HQ'])
# SMALLSTACK/POT
# 4
# 192
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 192
# "p2" declared "call:0"
# "['p1']" won the round 4 (stack = {'p1': 196, 'p2': 204})
# Started the round 5
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 194
# "p2" declared "call:2"
# SMALLSTACK/POT
# 4
# 194
# "p1" declared "call:2"
# Street "flop" started. (community card = ['C6', 'D5', 'SQ'])
# SMALLSTACK/POT
# 4
# 194
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 194
# "p1" declared "call:0"
# Street "turn" started. (community card = ['C6', 'D5', 'SQ', 'HK'])
# SMALLSTACK/POT
# 4
# 194
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 194
# "p1" declared "call:0"
# Street "river" started. (community card = ['C6', 'D5', 'SQ', 'HK', 'D2'])
# SMALLSTACK/POT
# 4
# 194
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 194
# "p1" declared "call:0"
# "['p2']" won the round 5 (stack = {'p1': 194, 'p2': 206})
# Started the round 6
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 193
# "p1" declared "call:2"
# SMALLSTACK/POT
# 4
# 192
# "p2" declared "call:2"
# Street "flop" started. (community card = ['HA', 'C5', 'S4'])
# SMALLSTACK/POT
# 4
# 192
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 192
# "p2" declared "call:0"
# Street "turn" started. (community card = ['HA', 'C5', 'S4', 'S9'])
# SMALLSTACK/POT
# 4
# 192
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 192
# "p2" declared "call:0"
# Street "river" started. (community card = ['HA', 'C5', 'S4', 'S9', 'CQ'])
# SMALLSTACK/POT
# 4
# 192
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 192
# "p2" declared "call:0"
# "['p2']" won the round 6 (stack = {'p1': 192, 'p2': 208})
# Started the round 7
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 190
# "p2" declared "call:2"
# SMALLSTACK/POT
# 4
# 190
# "p1" declared "call:2"
# Street "flop" started. (community card = ['C2', 'SJ', 'HQ'])
# SMALLSTACK/POT
# 4
# 190
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 190
# "p1" declared "call:0"
# Street "turn" started. (community card = ['C2', 'SJ', 'HQ', 'DA'])
# SMALLSTACK/POT
# 4
# 190
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 190
# "p1" declared "call:0"
# Street "river" started. (community card = ['C2', 'SJ', 'HQ', 'DA', 'C8'])
# SMALLSTACK/POT
# 4
# 190
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 190
# "p1" declared "call:0"
# "['p2']" won the round 7 (stack = {'p1': 190, 'p2': 210})
# Started the round 8
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 189
# "p1" declared "call:2"
# SMALLSTACK/POT
# 4
# 188
# "p2" declared "call:2"
# Street "flop" started. (community card = ['S8', 'SK', 'D3'])
# SMALLSTACK/POT
# 4
# 188
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 188
# "p2" declared "call:0"
# Street "turn" started. (community card = ['S8', 'SK', 'D3', 'H3'])
# SMALLSTACK/POT
# 4
# 188
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 188
# "p2" declared "call:0"
# Street "river" started. (community card = ['S8', 'SK', 'D3', 'H3', 'D9'])
# SMALLSTACK/POT
# 4
# 188
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 188
# "p2" declared "call:0"
# "['p2']" won the round 8 (stack = {'p1': 188, 'p2': 212})
# Started the round 9
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 186
# "p2" declared "call:2"
# SMALLSTACK/POT
# 4
# 186
# "p1" declared "call:2"
# Street "flop" started. (community card = ['S2', 'SJ', 'C6'])
# SMALLSTACK/POT
# 4
# 186
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 186
# "p1" declared "call:0"
# Street "turn" started. (community card = ['S2', 'SJ', 'C6', 'S3'])
# SMALLSTACK/POT
# 4
# 186
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 186
# "p1" declared "call:0"
# Street "river" started. (community card = ['S2', 'SJ', 'C6', 'S3', 'H3'])
# SMALLSTACK/POT
# 4
# 186
# "p2" declared "call:0"
# SMALLSTACK/POT
# 4
# 186
# "p1" declared "call:0"
# "['p2']" won the round 9 (stack = {'p1': 186, 'p2': 214})
# Started the round 10
# Street "preflop" started. (community card = [])
# SMALLSTACK/POT
# 3
# 185
# "p1" declared "call:2"
# SMALLSTACK/POT
# 4
# 184
# "p2" declared "call:2"
# Street "flop" started. (community card = ['D2', 'SA', 'H7'])
# SMALLSTACK/POT
# 4
# 184
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 184
# "p2" declared "call:0"
# Street "turn" started. (community card = ['D2', 'SA', 'H7', 'DT'])
# SMALLSTACK/POT
# 4
# 184
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 184
# "p2" declared "call:0"
# Street "river" started. (community card = ['D2', 'SA', 'H7', 'DT', 'S3'])
# SMALLSTACK/POT
# 4
# 184
# "p1" declared "call:0"
# SMALLSTACK/POT
# 4
# 184
# "p2" declared "call:0"
# "['p2']" won the round 10 (stack = {'p1': 184, 'p2': 216})

# %%
#TODO figure out action output space and state input space


#https://github.com/ishikota/PyPokerEngine
#https://ishikota.github.io/PyPokerEngine/

# !pip install pypokerengine

from pypokerengine.players import BasePokerPlayer

from pypokerengine.utils.game_state_utils import restore_game_state

STATE_SIZE = 369
STATE_SIZE2 = 369
ACTIONS = 6

model1 = ReinforceWithBaseline(STATE_SIZE2, ACTIONS)
model2 = ReinforceWithBaseline(STATE_SIZE, ACTIONS)

totalactions = {'call': 0, 'fold': 0, 'raise': 0}
totalactions1 = {'call': 0, 'fold': 0, 'raise': 0}

totalnetgain = 0

learningrate = 0.005

beta = 1.0

class FishPlayer(BasePokerPlayer):  # Do not forget to make parent class as "BasePokerPlayer"

    name = ""
    startstack = 0
    endstack = 0

    rewards = []
    states = []
    actions = []

    count = 0

    #  we define the logic to make an action through this method. (so this method would be the core of your AI)
    def declare_action(self, valid_actions, hole_card, round_state):

        card_ref = ['2','3','4','5','6','7','8','9','T','J','Q','K','A']

        init_array = [np.zeros((4,13)) for i in range(0,5)]
        for indexx, card in enumerate(round_state['community_card']):
          face = card_ref.index(card[1])
          if card[0] == 'H':
            init_array[indexx][0][face] = 1
          elif card[0] == 'D':
            init_array[indexx][1][face] = 1
          elif card[0] == 'C':
            init_array[indexx][2][face] = 1
          elif card[0] == 'S':
            init_array[indexx][3][face] = 1

        '''init_array = np.zeros(25)
        for indexx, card in enumerate(round_state['community_card']):
          face = card_ref.index(card[1])
          if card[0] == 'H':
            init_array[0 + 5*indexx] = 1
          elif card[0] == 'D':
            init_array[1 + 5*indexx] = 1
          elif card[0] == 'C':
            init_array[2 + 5*indexx] = 1
          elif card[0] == 'S':
            init_array[3 + 5*indexx] = 1

          init_array[4 + 5*indexx] = face'''
        #create flattened array

        flattened = np.array(init_array).flatten()

        init_array = [np.zeros((4,13)) for i in range(0,2)]
        for indexx, card in enumerate(hole_card):
          face = card_ref.index(card[1])
          if card[0] == 'H':
            init_array[indexx][0][face] = 1
          elif card[0] == 'D':
            init_array[indexx][1][face] = 1
          elif card[0] == 'C':
            init_array[indexx][2][face] = 1
          elif card[0] == 'S':
            init_array[indexx][3][face] = 1
        #create flattened array

        init_array = np.array(init_array)
        #create flattened array

        flattened = np.concatenate([init_array.flatten(), flattened])

        #allocate bigblind/pot and small stack/pot ratio vectors
        bigblindratio = np.zeros((1,10))
        smallstackratio = np.zeros((1,10))

        #find big blind stack, smallest stack
        pot = round_state['pot']['main']['amount']
        bbstack = round_state['seats'][round_state['big_blind_pos']]['stack']
        smallstack = min([round_state['seats'][i]['stack'] for i in range(0,len(round_state['seats']))])

        pos = np.zeros(1)

        if round_state['big_blind_pos'] == 0:
          pos[0] = 1

        street = np.zeros(4)

        if round_state['street'] == 'preflop':
          street[0] = 1

        if round_state['street'] == 'flop':
          street[1] = 1

        if round_state['street'] == 'turn':
          street[2] = 1

        if round_state['street'] == 'river':
          street[3] = 1

        #add this information to the gamestate vector
        flattened = np.concatenate([flattened, pos, street])

        #get information on most recent action:
        action_set = ['SMALLBLIND', 'BIGBLIND', 'CALL', 'FOLD', 'RAISE']

        if len(round_state['action_histories'][round_state['street']]) != 0:
          last_move = round_state['action_histories'][round_state['street']][-1]
          last_move_array = np.zeros((1,2))
          last_move_array[0][0] = action_set.index(last_move['action'])
          last_move_array[0][1] = last_move['amount']

        else:
          last_move_array = np.zeros((1,2))

        #add information on most recent action to feature vector
        #state = np.concatenate([flattened, last_move_array.flatten()])
        state = flattened

        #print(state)
        print(len(state))

        probs = model1.call(tf.expand_dims(state, 0))

        p2 = np.array(probs)[0]

        print(p2)

        #p2 = np.exp(beta * p2)/np.sum(np.exp(beta * p2))
        p2 /= p2.sum()

        print("p1 probs: ")
        print(p2)

        output = np.random.choice([0,1,2,3,4,5], 1, p=p2)

        action = 'raise'

        amount = 0

        print(self.name + " hole cards: ")
        print(hole_card)
        print(valid_actions)

        if output == 0:

          action = 'fold'

          if valid_actions[1]['amount'] == 0:

            action = 'call'

        elif output == 1:

          action = 'call'
          amount = valid_actions[1]['amount']

        elif output == 2:

          amount = (valid_actions[2]['amount']['min']) + (0.25 * round_state['pot']['main']['amount'])

        elif output == 3:

          amount = (valid_actions[2]['amount']['min']) + (0.5 * round_state['pot']['main']['amount'])

        elif output == 4:

          amount = (valid_actions[2]['amount']['min']) + (0.75 * round_state['pot']['main']['amount'])

        elif output == 5:

          amount = (valid_actions[2]['amount']['min']) + (round_state['pot']['main']['amount'])

        if (action == 'raise' and valid_actions[2]['amount']['max'] == -1):

          action = 'call'
          amount = valid_actions[1]['amount']

        if (action == "raise" and amount > valid_actions[2]['amount']['max']):
          amount = valid_actions[2]['amount']['max']

        totalactions[action] += 1

        self.states.append(state)
        self.actions.append(output)
        self.rewards.append(0)

        return action, amount   # action returned here is sent to the poker engine

    def receive_game_start_message(self, game_info):
        pass

    def receive_round_start_message(self, round_count, hole_card, seats):

        if self.count == 0:

          self.actions = []
          self.states = []
          self.rewards = []

        if (seats[0]['name'] == self.name):
          self.startstack = seats[0]['stack']

        if (seats[1]['name'] == self.name):
          self.startstack = seats[1]['stack']

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):

        if len(self.rewards) == 0:
          return

        if not self.rewards[len(self.rewards)-1] == 0:
          return

        seats = round_state['seats']

        if (seats[0]['name'] == self.name):

          if round_state['small_blind_pos'] == 0:
            self.startstack += 1
          else:
            self.startstack += 2

          self.endstack = seats[0]['stack']
          self.rewards[len(self.rewards)-1] = (self.endstack - self.startstack) * learningrate

        if (seats[1]['name'] == self.name):

          if round_state['small_blind_pos'] == 1:
            self.startstack += 1
          else:
            self.startstack += 2

          self.endstack = seats[1]['stack']
          self.rewards[len(self.rewards)-1] = (self.endstack - self.startstack) * learningrate


        print("p1 rewards: ")
        print(self.rewards)

        print("p1 actions map: ")
        print(totalactions)

        global totalnetgain
        totalnetgain += self.rewards[len(self.rewards) - 1]

        print("TOTALNETGAIN p1: ")
        print(totalnetgain)

        if self.count > 96:
          with tf.GradientTape() as tape:

            myloss = model1.loss(self.states, self.actions, self.rewards)

          gradients = tape.gradient(myloss, model1.trainable_variables)
          model1.optimizer.apply_gradients(zip(gradients, model1.trainable_variables))

          self.count = 0
        else:
          self.count += 1

    def __init__(self, n):

      self.name = n


class FishPlayer2(BasePokerPlayer):  # Do not forget to make parent class as "BasePokerPlayer"

    name = ""
    startstack = 0
    endstack = 0

    rewards = []
    states = []
    actions = []

    count = 0

    #  we define the logic to make an action through this method. (so this method would be the core of your AI)
    def declare_action(self, valid_actions, hole_card, round_state):
        # valid_actions format => [raise_action_info, call_action_info, fold_action_info]

        card_ref = ['2','3','4','5','6','7','8','9','T','J','Q','K','A']

        init_array = [np.zeros((4,13)) for i in range(0,5)]
        for indexx, card in enumerate(round_state['community_card']):
          face = card_ref.index(card[1])
          if card[0] == 'H':
            init_array[indexx][0][face] = 1
          elif card[0] == 'D':
            init_array[indexx][1][face] = 1
          elif card[0] == 'C':
            init_array[indexx][2][face] = 1
          elif card[0] == 'S':
            init_array[indexx][3][face] = 1

        '''init_array = np.zeros(25)
        for indexx, card in enumerate(round_state['community_card']):
          face = card_ref.index(card[1])
          if card[0] == 'H':
            init_array[0 + 5*indexx] = 1
          elif card[0] == 'D':
            init_array[1 + 5*indexx] = 1
          elif card[0] == 'C':
            init_array[2 + 5*indexx] = 1
          elif card[0] == 'S':
            init_array[3 + 5*indexx] = 1

          init_array[4 + 5*indexx] = face'''

        #create flattened array
        init_array = np.array(init_array)

        flattened = init_array.flatten()

        init_array = [np.zeros((4,13)) for i in range(0,2)]
        for indexx, card in enumerate(hole_card):
          face = card_ref.index(card[1])
          if card[0] == 'H':
            init_array[indexx][0][face] = 1
          elif card[0] == 'D':
            init_array[indexx][1][face] = 1
          elif card[0] == 'C':
            init_array[indexx][2][face] = 1
          elif card[0] == 'S':
            init_array[indexx][3][face] = 1
        #create flattened array

        init_array = np.array(init_array)

        flattened = np.concatenate([init_array.flatten(), flattened])

        #allocate bigblind/pot and small stack/pot ratio vectors
        bigblindratio = np.zeros((1,10))
        smallstackratio = np.zeros((1,10))

        #find big blind stack, smallest stack
        pot = round_state['pot']['main']['amount']
        bbstack = round_state['seats'][round_state['big_blind_pos']]['stack']
        smallstack = min([round_state['seats'][i]['stack'] for i in range(0,len(round_state['seats']))])

        #add this information to the gamestate vector
        #flattened = np.concatenate([flattened, np.array([pot, smallstack])])

        #get information on most recent action:
        action_set = ['SMALLBLIND', 'BIGBLIND', 'CALL', 'FOLD', 'RAISE']

        if len(round_state['action_histories'][round_state['street']]) != 0:
          last_move = round_state['action_histories'][round_state['street']][-1]
          last_move_array = np.zeros((1,2))
          last_move_array[0][0] = action_set.index(last_move['action'])
          last_move_array[0][1] = last_move['amount']

        else:
          last_move_array = np.zeros((1,2))

        #add information on most recent action to feature vector

        pos = np.zeros(1)

        if round_state['big_blind_pos'] == 1:
          pos[0] = 1

        street = np.zeros(4)

        if round_state['street'] == 'preflop':
          street[0] = 1

        if round_state['street'] == 'flop':
          street[1] = 1

        if round_state['street'] == 'turn':
          street[2] = 1

        if round_state['street'] == 'river':
          street[3] = 1

        #add this information to the gamestate vector
        state = np.concatenate([flattened, pos, street])

        probs = model2.call(tf.expand_dims(state, 0))[0]

        p2 = np.array(probs)

        print(p2)
        #p2 = np.exp(beta * p2)/np.sum(np.exp(beta * p2))
        p2 /= p2.sum()

        print("p2 probs: ")
        print(p2)

        output = np.random.choice([0,1,2,3,4,5], 1, p=p2)

        action = 'raise'
        amount = 0

        print(self.name + " hole cards: ")
        print(hole_card)
        print(valid_actions)

        if output == 0:

          action = 'fold'

          if valid_actions[1]['amount'] == 0:

            action = 'call'

        elif output == 1:

          action = 'call'
          amount = valid_actions[1]['amount']

        elif output == 2:

          amount = (valid_actions[2]['amount']['min']) + (0.25 * round_state['pot']['main']['amount'])

        elif output == 3:

          amount = (valid_actions[2]['amount']['min']) + (0.5 * round_state['pot']['main']['amount'])

        elif output == 4:

          amount = (valid_actions[2]['amount']['min']) + (0.75 * round_state['pot']['main']['amount'])

        elif output == 5:

          amount = (valid_actions[2]['amount']['min']) + (round_state['pot']['main']['amount'])


        if (action == 'raise' and valid_actions[2]['amount']['max'] == -1):

          action = 'call'
          amount = valid_actions[1]['amount']

        if (action == "raise" and amount > valid_actions[2]['amount']['max']):
          amount = valid_actions[2]['amount']['max']

        totalactions1[action] += 1

        self.states.append(state)
        self.actions.append(output)
        self.rewards.append(0)

        return action, amount   # action returned here is sent to the poker engine

    def receive_game_start_message(self, game_info):
        pass

    def receive_round_start_message(self, round_count, hole_card, seats):

        if self.count == 0:
          self.actions = []
          self.states = []
          self.rewards = []

        if (seats[0]['name'] == self.name):
          self.startstack = seats[0]['stack']

        if (seats[1]['name'] == self.name):
          self.startstack = seats[1]['stack']

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):

        if len(self.rewards) == 0:
          return

        if not self.rewards[len(self.rewards)-1] == 0:
          return

        seats = round_state['seats']

        if (seats[0]['name'] == self.name):

          if round_state['small_blind_pos'] == 0:
            self.startstack += 1
          else:
            self.startstack += 2

          self.endstack = seats[0]['stack']
          self.rewards[len(self.rewards)-1] = (self.endstack - self.startstack) * learningrate

        if (seats[1]['name'] == self.name):

          if round_state['small_blind_pos'] == 1:
            self.startstack += 1
          else:
            self.startstack += 2

          self.endstack = seats[1]['stack']
          self.rewards[len(self.rewards)-1] = (self.endstack - self.startstack) * learningrate


        print("p2 reward: ")
        print(self.rewards)

        print("p2 actions map: ")
        print(totalactions1)

        if self.count > 96:

          with tf.GradientTape() as tape:

            myloss = model2.loss(self.states, self.actions, self.rewards)

          gradients = tape.gradient(myloss, model2.trainable_variables)
          model2.optimizer.apply_gradients(zip(gradients, model2.trainable_variables))

          self.count = 0

        else:

          self.count += 1

    def __init__(self, n):

      self.name = n

from pypokerengine.api.game import setup_config, start_poker

config = setup_config(max_round=50, initial_stack=200, small_blind_amount=1)
config.register_player(name="p1", algorithm=FishPlayer("p1"))
config.register_player(name="p2", algorithm=FishPlayer2("p2"))

for i in range(0, 25000):
  game_result = start_poker(config, verbose=1)

  print("ROUND : " + str(i))
# Out:
# Streaming output truncated to the last 5000 lines.
# TOTALNETGAIN p1:
# 3963.2107861393
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663156, 'raise': 131173}
# Started the round 21
# Street "preflop" started. (community card = [])
# [9.9602950e-01 2.3854910e-04 5.7090941e-04 1.1586446e-03 1.2210511e-04
#  1.8803807e-03]
# p2 probs:
# [9.9602938e-01 2.3854907e-04 5.7090935e-04 1.1586444e-03 1.2210509e-04
#  1.8803804e-03]
# p2 hole cards:
# ['DK', 'SJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 176}}]
# "p2" declared "fold:0"
# "['p1']" won the round 21 (stack = {'p1': 222.5, 'p2': 175})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663157, 'raise': 131173}
# Started the round 22
# Street "preflop" started. (community card = [])
# 369
# [0.17336428 0.12256745 0.22792044 0.16107705 0.18451089 0.13055989]
# p1 probs:
# [0.17336428 0.12256745 0.22792044 0.16107705 0.18451089 0.13055989]
# p1 hole cards:
# ['C4', 'H6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 222.5}}]
# "p1" declared "fold:0"
# "['p2']" won the round 22 (stack = {'p1': 221.5, 'p2': 176})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005]
# p1 actions map:
# {'call': 78201, 'fold': 87954, 'raise': 376696}
# TOTALNETGAIN p1:
# 3963.2057861393
# Started the round 23
# Street "preflop" started. (community card = [])
# [9.8771870e-01 9.6940866e-04 1.9322912e-03 3.5915703e-03 5.4300384e-04
#  5.2450164e-03]
# p2 probs:
# [9.8771870e-01 9.6940866e-04 1.9322912e-03 3.5915703e-03 5.4300384e-04
#  5.2450164e-03]
# p2 hole cards:
# ['CA', 'HJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 176}}]
# "p2" declared "fold:0"
# "['p1']" won the round 23 (stack = {'p1': 222.5, 'p2': 175})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663158, 'raise': 131173}
# Started the round 24
# Street "preflop" started. (community card = [])
# 369
# [0.19958964 0.10050571 0.29378816 0.12521362 0.1628665  0.11803645]
# p1 probs:
# [0.19958964 0.10050571 0.29378816 0.12521362 0.1628665  0.11803645]
# p1 hole cards:
# ['D2', 'HA']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 222.5}}]
# "p1" declared "call:2"
# [9.9899405e-01 5.0572984e-05 1.3096833e-04 3.1681423e-04 1.8345620e-05
#  4.8921304e-04]
# p2 probs:
# [9.9899411e-01 5.0572988e-05 1.3096834e-04 3.1681426e-04 1.8345621e-05
#  4.8921310e-04]
# p2 hole cards:
# ['CA', 'CQ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 175}}]
# "p2" declared "fold:0"
# "['p1']" won the round 24 (stack = {'p1': 224.5, 'p2': 173})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01]
# p1 actions map:
# {'call': 78202, 'fold': 87954, 'raise': 376696}
# TOTALNETGAIN p1:
# 3963.2157861393002
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663159, 'raise': 131173}
# Started the round 25
# Street "preflop" started. (community card = [])
# [9.9060577e-01 7.2867179e-04 1.5646962e-03 2.8055317e-03 3.7771824e-04
#  3.9174953e-03]
# p2 probs:
# [9.9060589e-01 7.2867185e-04 1.5646964e-03 2.8055320e-03 3.7771830e-04
#  3.9174957e-03]
# p2 hole cards:
# ['H5', 'D9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 173}}]
# "p2" declared "fold:0"
# "['p1']" won the round 25 (stack = {'p1': 225.5, 'p2': 172})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663160, 'raise': 131173}
# Started the round 26
# Street "preflop" started. (community card = [])
# 369
# [0.18005131 0.13496363 0.21457362 0.15969482 0.16863874 0.1420779 ]
# p1 probs:
# [0.18005131 0.13496363 0.21457362 0.15969482 0.16863874 0.1420779 ]
# p1 hole cards:
# ['DJ', 'H3']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 225.5}}]
# "p1" declared "raise:6"
# [9.9875319e-01 5.9716582e-05 1.7352392e-04 3.5831810e-04 2.1721695e-05
#  6.3354935e-04]
# p2 probs:
# [9.9875319e-01 5.9716582e-05 1.7352392e-04 3.5831810e-04 2.1721695e-05
#  6.3354935e-04]
# p2 hole cards:
# ['H7', 'C2']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 6}, {'action': 'raise', 'amount': {'min': 10, 'max': 172}}]
# "p2" declared "fold:0"
# "['p1']" won the round 26 (stack = {'p1': 227.5, 'p2': 170})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01]
# p1 actions map:
# {'call': 78202, 'fold': 87954, 'raise': 376697}
# TOTALNETGAIN p1:
# 3963.2257861393005
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663161, 'raise': 131173}
# Started the round 27
# Street "preflop" started. (community card = [])
# [9.9006724e-01 7.6759508e-04 1.6305890e-03 2.7832643e-03 3.4612344e-04
#  4.4050999e-03]
# p2 probs:
# [9.9006736e-01 7.6759519e-04 1.6305892e-03 2.7832645e-03 3.4612347e-04
#  4.4051004e-03]
# p2 hole cards:
# ['D8', 'DT']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 170}}]
# "p2" declared "fold:0"
# "['p1']" won the round 27 (stack = {'p1': 228.5, 'p2': 169})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663162, 'raise': 131173}
# Started the round 28
# Street "preflop" started. (community card = [])
# 369
# [0.17990452 0.11353181 0.24372494 0.15424955 0.17217007 0.13641903]
# p1 probs:
# [0.17990452 0.11353181 0.24372494 0.15424955 0.17217007 0.13641903]
# p1 hole cards:
# ['C4', 'HQ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 228.5}}]
# "p1" declared "raise:3.75"
# [9.97788310e-01 1.18514916e-04 3.65136249e-04 6.16677396e-04
#  4.97197252e-05 1.06156326e-03]
# p2 probs:
# [9.9778843e-01 1.1851493e-04 3.6513628e-04 6.1667745e-04 4.9719732e-05
#  1.0615634e-03]
# p2 hole cards:
# ['H6', 'D9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 3.75}, {'action': 'raise', 'amount': {'min': 5.5, 'max': 169}}]
# "p2" declared "fold:0"
# "['p1']" won the round 28 (stack = {'p1': 229.75, 'p2': 167})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625]
# p1 actions map:
# {'call': 78202, 'fold': 87954, 'raise': 376698}
# TOTALNETGAIN p1:
# 3963.2320361393004
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663163, 'raise': 131173}
# Started the round 29
# Street "preflop" started. (community card = [])
# [0.95074916 0.00468269 0.0088054  0.01319022 0.0034824  0.01909017]
# p2 probs:
# [0.95074916 0.00468269 0.0088054  0.01319022 0.0034824  0.01909017]
# p2 hole cards:
# ['S7', 'S6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 167}}]
# "p2" declared "fold:0"
# "['p1']" won the round 29 (stack = {'p1': 230.75, 'p2': 166})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663164, 'raise': 131173}
# Started the round 30
# Street "preflop" started. (community card = [])
# 369
# [0.19669452 0.11332339 0.2664609  0.12978044 0.15602817 0.13771255]
# p1 probs:
# [0.19669454 0.1133234  0.26646093 0.12978046 0.15602818 0.13771257]
# p1 hole cards:
# ['S5', 'D6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 230.75}}]
# "p1" declared "fold:0"
# "['p2']" won the round 30 (stack = {'p1': 229.75, 'p2': 167})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376698}
# TOTALNETGAIN p1:
# 3963.2270361393003
# Started the round 31
# Street "preflop" started. (community card = [])
# [9.8436385e-01 1.2000127e-03 2.5516169e-03 4.3537230e-03 7.1298709e-04
#  6.8177604e-03]
# p2 probs:
# [9.8436391e-01 1.2000129e-03 2.5516171e-03 4.3537235e-03 7.1298715e-04
#  6.8177609e-03]
# p2 hole cards:
# ['S2', 'SK']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 167}}]
# "p2" declared "fold:0"
# "['p1']" won the round 31 (stack = {'p1': 230.75, 'p2': 166})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663165, 'raise': 131173}
# Started the round 32
# Street "preflop" started. (community card = [])
# 369
# [0.19292673 0.11119597 0.2614244  0.13777244 0.1554376  0.14124288]
# p1 probs:
# [0.19292673 0.11119597 0.2614244  0.13777244 0.1554376  0.14124288]
# p1 hole cards:
# ['D5', 'DT']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 230.75}}]
# "p1" declared "raise:3.75"
# [9.9926645e-01 2.9716743e-05 8.7722263e-05 2.0602737e-04 1.1222754e-05
#  3.9894582e-04]
# p2 probs:
# [9.99266326e-01 2.97167389e-05 8.77222556e-05 2.06027340e-04
#  1.12227535e-05 3.98945762e-04]
# p2 hole cards:
# ['HA', 'H9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 3.75}, {'action': 'raise', 'amount': {'min': 5.5, 'max': 166}}]
# "p2" declared "fold:0"
# "['p1']" won the round 32 (stack = {'p1': 232.0, 'p2': 164})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376699}
# TOTALNETGAIN p1:
# 3963.2332861393
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663166, 'raise': 131173}
# Started the round 33
# Street "preflop" started. (community card = [])
# [9.8792738e-01 8.2936074e-04 1.8022232e-03 3.3701123e-03 5.1084079e-04
#  5.5600628e-03]
# p2 probs:
# [9.8792750e-01 8.2936086e-04 1.8022234e-03 3.3701127e-03 5.1084085e-04
#  5.5600633e-03]
# p2 hole cards:
# ['DJ', 'C5']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 164}}]
# "p2" declared "fold:0"
# "['p1']" won the round 33 (stack = {'p1': 233.0, 'p2': 163})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663167, 'raise': 131173}
# Started the round 34
# Street "preflop" started. (community card = [])
# 369
# [0.18284312 0.12714192 0.2289404  0.15079623 0.1648003  0.14547805]
# p1 probs:
# [0.18284312 0.12714192 0.2289404  0.15079623 0.1648003  0.14547805]
# p1 hole cards:
# ['D6', 'D8']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 233.0}}]
# "p1" declared "raise:6"
# [9.9970788e-01 1.0299473e-05 3.6209331e-05 8.6354448e-05 3.1185900e-06
#  1.5616353e-04]
# p2 probs:
# [9.9970788e-01 1.0299473e-05 3.6209331e-05 8.6354448e-05 3.1185900e-06
#  1.5616353e-04]
# p2 hole cards:
# ['HT', 'C4']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 6}, {'action': 'raise', 'amount': {'min': 10, 'max': 163}}]
# "p2" declared "fold:0"
# "['p1']" won the round 34 (stack = {'p1': 235.0, 'p2': 161})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376700}
# TOTALNETGAIN p1:
# 3963.2432861393004
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663168, 'raise': 131173}
# Started the round 35
# Street "preflop" started. (community card = [])
# [9.9707866e-01 1.5372259e-04 4.3375598e-04 8.0915121e-04 7.4695185e-05
#  1.4501252e-03]
# p2 probs:
# [9.9707854e-01 1.5372258e-04 4.3375592e-04 8.0915110e-04 7.4695177e-05
#  1.4501251e-03]
# p2 hole cards:
# ['S4', 'HQ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 161}}]
# "p2" declared "fold:0"
# "['p1']" won the round 35 (stack = {'p1': 236.0, 'p2': 160})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663169, 'raise': 131173}
# Started the round 36
# Street "preflop" started. (community card = [])
# 369
# [0.18621118 0.11003772 0.2611021  0.14442334 0.17379177 0.12443393]
# p1 probs:
# [0.18621118 0.11003772 0.2611021  0.14442334 0.17379177 0.12443393]
# p1 hole cards:
# ['DJ', 'DA']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 236.0}}]
# "p1" declared "raise:6"
# [9.9832958e-01 8.7348060e-05 2.3974112e-04 4.8871309e-04 3.4649496e-05
#  8.2010427e-04]
# p2 probs:
# [9.9832946e-01 8.7348053e-05 2.3974109e-04 4.8871303e-04 3.4649493e-05
#  8.2010415e-04]
# p2 hole cards:
# ['SK', 'SA']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 6}, {'action': 'raise', 'amount': {'min': 10, 'max': 160}}]
# "p2" declared "fold:0"
# "['p1']" won the round 36 (stack = {'p1': 238.0, 'p2': 158})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376701}
# TOTALNETGAIN p1:
# 3963.2532861393006
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663170, 'raise': 131173}
# Started the round 37
# Street "preflop" started. (community card = [])
# [9.9392670e-01 4.0698517e-04 9.0474059e-04 1.8155016e-03 2.0916182e-04
#  2.7368979e-03]
# p2 probs:
# [9.9392670e-01 4.0698517e-04 9.0474059e-04 1.8155016e-03 2.0916182e-04
#  2.7368979e-03]
# p2 hole cards:
# ['CT', 'D7']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 158}}]
# "p2" declared "fold:0"
# "['p1']" won the round 37 (stack = {'p1': 239.0, 'p2': 157})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663171, 'raise': 131173}
# Started the round 38
# Street "preflop" started. (community card = [])
# 369
# [0.18738522 0.13317631 0.2200358  0.15074    0.16110088 0.14756182]
# p1 probs:
# [0.18738522 0.13317631 0.2200358  0.15074    0.16110088 0.14756182]
# p1 hole cards:
# ['H8', 'CQ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 239.0}}]
# "p1" declared "raise:5.25"
# [9.9829596e-01 8.4742445e-05 2.3400618e-04 4.8015843e-04 3.2792679e-05
#  8.7227050e-04]
# p2 probs:
# [9.9829602e-01 8.4742453e-05 2.3400619e-04 4.8015846e-04 3.2792683e-05
#  8.7227055e-04]
# p2 hole cards:
# ['CT', 'SK']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 5.25}, {'action': 'raise', 'amount': {'min': 8.5, 'max': 157}}]
# "p2" declared "fold:0"
# "['p1']" won the round 38 (stack = {'p1': 240.75, 'p2': 155})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376702}
# TOTALNETGAIN p1:
# 3963.2620361393006
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663172, 'raise': 131173}
# Started the round 39
# Street "preflop" started. (community card = [])
# [9.9653244e-01 2.1745975e-04 5.4059771e-04 1.0394886e-03 9.5541007e-05
#  1.5744066e-03]
# p2 probs:
# [9.9653250e-01 2.1745976e-04 5.4059777e-04 1.0394887e-03 9.5541014e-05
#  1.5744067e-03]
# p2 hole cards:
# ['D7', 'S9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 155}}]
# "p2" declared "fold:0"
# "['p1']" won the round 39 (stack = {'p1': 241.75, 'p2': 154})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663173, 'raise': 131173}
# Started the round 40
# Street "preflop" started. (community card = [])
# 369
# [0.17641577 0.12588532 0.22695814 0.1521391  0.1831592  0.13544244]
# p1 probs:
# [0.17641577 0.12588532 0.22695814 0.1521391  0.1831592  0.13544244]
# p1 hole cards:
# ['H5', 'H6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 241.75}}]
# "p1" declared "raise:5.25"
# [9.9918705e-01 3.7925471e-05 1.0417184e-04 2.4010339e-04 1.1580236e-05
#  4.1919484e-04]
# p2 probs:
# [9.9918705e-01 3.7925471e-05 1.0417184e-04 2.4010339e-04 1.1580236e-05
#  4.1919484e-04]
# p2 hole cards:
# ['H9', 'H4']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 5.25}, {'action': 'raise', 'amount': {'min': 8.5, 'max': 154}}]
# "p2" declared "fold:0"
# "['p1']" won the round 40 (stack = {'p1': 243.5, 'p2': 152})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376703}
# TOTALNETGAIN p1:
# 3963.2707861393005
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663174, 'raise': 131173}
# Started the round 41
# Street "preflop" started. (community card = [])
# [9.8832893e-01 8.5915090e-04 1.8994508e-03 3.2702435e-03 4.5698904e-04
#  5.1851985e-03]
# p2 probs:
# [9.8832899e-01 8.5915095e-04 1.8994509e-03 3.2702438e-03 4.5698907e-04
#  5.1851990e-03]
# p2 hole cards:
# ['CK', 'H3']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 152}}]
# "p2" declared "fold:0"
# "['p1']" won the round 41 (stack = {'p1': 244.5, 'p2': 151})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663175, 'raise': 131173}
# Started the round 42
# Street "preflop" started. (community card = [])
# 369
# [0.18027756 0.14173691 0.22006257 0.1491414  0.14786378 0.16091785]
# p1 probs:
# [0.18027756 0.14173691 0.22006257 0.1491414  0.14786378 0.16091785]
# p1 hole cards:
# ['ST', 'C3']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 244.5}}]
# "p1" declared "raise:3.75"
# [9.9889261e-01 5.0530725e-05 1.5394720e-04 3.2214829e-04 2.0602030e-05
#  5.6030625e-04]
# p2 probs:
# [9.9889237e-01 5.0530714e-05 1.5394716e-04 3.2214820e-04 2.0602025e-05
#  5.6030613e-04]
# p2 hole cards:
# ['DT', 'D5']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 3.75}, {'action': 'raise', 'amount': {'min': 5.5, 'max': 151}}]
# "p2" declared "fold:0"
# "['p1']" won the round 42 (stack = {'p1': 245.75, 'p2': 149})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376704}
# TOTALNETGAIN p1:
# 3963.2770361393004
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663176, 'raise': 131173}
# Started the round 43
# Street "preflop" started. (community card = [])
# [9.9359494e-01 4.2913065e-04 9.0807414e-04 1.8741073e-03 2.1087850e-04
#  2.9829743e-03]
# p2 probs:
# [9.9359483e-01 4.2913060e-04 9.0807403e-04 1.8741071e-03 2.1087847e-04
#  2.9829738e-03]
# p2 hole cards:
# ['H9', 'S2']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 149}}]
# "p2" declared "fold:0"
# "['p1']" won the round 43 (stack = {'p1': 246.75, 'p2': 148})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663177, 'raise': 131173}
# Started the round 44
# Street "preflop" started. (community card = [])
# 369
# [0.1849579  0.11718588 0.22301641 0.15567377 0.18490557 0.13426043]
# p1 probs:
# [0.18495792 0.11718589 0.22301643 0.15567379 0.18490559 0.13426045]
# p1 hole cards:
# ['D7', 'S6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 246.75}}]
# "p1" declared "raise:5.25"
# [9.9874485e-01 5.8195463e-05 1.8232422e-04 3.5508248e-04 2.2720227e-05
#  6.3685887e-04]
# p2 probs:
# [9.9874485e-01 5.8195463e-05 1.8232422e-04 3.5508248e-04 2.2720227e-05
#  6.3685887e-04]
# p2 hole cards:
# ['H2', 'H5']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 5.25}, {'action': 'raise', 'amount': {'min': 8.5, 'max': 148}}]
# "p2" declared "fold:0"
# "['p1']" won the round 44 (stack = {'p1': 248.5, 'p2': 146})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625, 0.00875]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376705}
# TOTALNETGAIN p1:
# 3963.2857861393004
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663178, 'raise': 131173}
# Started the round 45
# Street "preflop" started. (community card = [])
# [9.8741257e-01 9.5349463e-04 2.2054487e-03 3.5208098e-03 5.6585943e-04
#  5.3420183e-03]
# p2 probs:
# [9.8741233e-01 9.5349440e-04 2.2054482e-03 3.5208089e-03 5.6585931e-04
#  5.3420169e-03]
# p2 hole cards:
# ['D3', 'D9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 146}}]
# "p2" declared "fold:0"
# "['p1']" won the round 45 (stack = {'p1': 249.5, 'p2': 145})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663179, 'raise': 131173}
# Started the round 46
# Street "preflop" started. (community card = [])
# 369
# [0.19779187 0.10453333 0.2844978  0.12801822 0.15503144 0.13012734]
# p1 probs:
# [0.19779187 0.10453333 0.2844978  0.12801822 0.15503144 0.13012734]
# p1 hole cards:
# ['S5', 'DQ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 249.5}}]
# "p1" declared "raise:4.5"
# [9.9654800e-01 1.9979439e-04 5.4542330e-04 9.7334594e-04 9.0166272e-05
#  1.6433542e-03]
# p2 probs:
# [9.9654788e-01 1.9979436e-04 5.4542325e-04 9.7334583e-04 9.0166264e-05
#  1.6433540e-03]
# p2 hole cards:
# ['S2', 'DA']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 4.5}, {'action': 'raise', 'amount': {'min': 7.0, 'max': 145}}]
# "p2" declared "fold:0"
# "['p1']" won the round 46 (stack = {'p1': 251.0, 'p2': 143})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625, 0.00875, 0.0075]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376706}
# TOTALNETGAIN p1:
# 3963.2932861393006
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663180, 'raise': 131173}
# Started the round 47
# Street "preflop" started. (community card = [])
# [9.9269497e-01 4.9668743e-04 1.2359526e-03 2.0171283e-03 2.4733340e-04
#  3.3080396e-03]
# p2 probs:
# [9.9269485e-01 4.9668737e-04 1.2359525e-03 2.0171280e-03 2.4733337e-04
#  3.3080392e-03]
# p2 hole cards:
# ['C5', 'CJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 143}}]
# "p2" declared "fold:0"
# "['p1']" won the round 47 (stack = {'p1': 252.0, 'p2': 142})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663181, 'raise': 131173}
# Started the round 48
# Street "preflop" started. (community card = [])
# 369
# [0.19367811 0.09514793 0.30977517 0.12451684 0.16118525 0.11569673]
# p1 probs:
# [0.19367811 0.09514793 0.30977517 0.12451684 0.16118525 0.11569673]
# p1 hole cards:
# ['CT', 'HA']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 252.0}}]
# "p1" declared "raise:6"
# [9.9928707e-01 2.9887915e-05 9.1946051e-05 2.0055476e-04 1.0632034e-05
#  3.7993025e-04]
# p2 probs:
# [9.9928707e-01 2.9887915e-05 9.1946051e-05 2.0055476e-04 1.0632034e-05
#  3.7993025e-04]
# p2 hole cards:
# ['CQ', 'HK']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 6}, {'action': 'raise', 'amount': {'min': 10, 'max': 142}}]
# "p2" declared "fold:0"
# "['p1']" won the round 48 (stack = {'p1': 254.0, 'p2': 140})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625, 0.00875, 0.0075, 0.01]
# p1 actions map:
# {'call': 78202, 'fold': 87955, 'raise': 376707}
# TOTALNETGAIN p1:
# 3963.303286139301
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663182, 'raise': 131173}
# Started the round 49
# Street "preflop" started. (community card = [])
# [9.9112564e-01 6.5368577e-04 1.3765390e-03 2.5674531e-03 3.2426117e-04
#  3.9524543e-03]
# p2 probs:
# [9.9112564e-01 6.5368577e-04 1.3765390e-03 2.5674531e-03 3.2426117e-04
#  3.9524543e-03]
# p2 hole cards:
# ['SK', 'H8']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 140}}]
# "p2" declared "fold:0"
# "['p1']" won the round 49 (stack = {'p1': 255.0, 'p2': 139})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663183, 'raise': 131173}
# Started the round 50
# Street "preflop" started. (community card = [])
# 369
# [0.19689888 0.12352005 0.25800502 0.12727873 0.14395285 0.15034449]
# p1 probs:
# [0.19689888 0.12352005 0.25800502 0.12727873 0.14395285 0.15034449]
# p1 hole cards:
# ['HT', 'CJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 255.0}}]
# "p1" declared "call:2"
# [9.9954766e-01 1.5099980e-05 5.3614345e-05 1.2125211e-04 5.5895885e-06
#  2.5670955e-04]
# p2 probs:
# [9.99547780e-01 1.50999822e-05 5.36143525e-05 1.21252124e-04
#  5.58958891e-06 2.56709580e-04]
# p2 hole cards:
# ['DJ', 'C3']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 139}}]
# "p2" declared "fold:0"
# "['p1']" won the round 50 (stack = {'p1': 257.0, 'p2': 137})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625, 0.00875, 0.0075, 0.01, 0.01]
# p1 actions map:
# {'call': 78203, 'fold': 87955, 'raise': 376707}
# TOTALNETGAIN p1:
# 3963.313286139301
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663184, 'raise': 131173}
# ROUND : 24995
# Started the round 1
# Street "preflop" started. (community card = [])
# [9.9357188e-01 4.1035115e-04 9.5101498e-04 1.8204118e-03 2.0998740e-04
#  3.0362599e-03]
# p2 probs:
# [9.9357200e-01 4.1035120e-04 9.5101510e-04 1.8204120e-03 2.0998743e-04
#  3.0362604e-03]
# p2 hole cards:
# ['C2', 'SJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 200}}]
# "p2" declared "fold:0"
# "['p1']" won the round 1 (stack = {'p1': 201, 'p2': 199})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663185, 'raise': 131173}
# Started the round 2
# Street "preflop" started. (community card = [])
# 369
# [0.19018751 0.12475623 0.23260507 0.15230921 0.15982114 0.14032082]
# p1 probs:
# [0.19018753 0.12475624 0.23260508 0.15230922 0.15982115 0.14032084]
# p1 hole cards:
# ['C2', 'C6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 201}}]
# "p1" declared "raise:3.75"
# [9.9899060e-01 4.6704987e-05 1.4525137e-04 2.9243363e-04 1.7260290e-05
#  5.0764938e-04]
# p2 probs:
# [9.9899065e-01 4.6704990e-05 1.4525138e-04 2.9243366e-04 1.7260292e-05
#  5.0764944e-04]
# p2 hole cards:
# ['C4', 'H9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 3.75}, {'action': 'raise', 'amount': {'min': 5.5, 'max': 199}}]
# "p2" declared "fold:0"
# "['p1']" won the round 2 (stack = {'p1': 202.25, 'p2': 197})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625, 0.00875, 0.0075, 0.01, 0.01, 0.00625]
# p1 actions map:
# {'call': 78203, 'fold': 87955, 'raise': 376708}
# TOTALNETGAIN p1:
# 3963.319536139301
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663186, 'raise': 131173}
# Started the round 3
# Street "preflop" started. (community card = [])
# [9.9160099e-01 5.6857278e-04 1.3284908e-03 2.3935570e-03 3.1437667e-04
#  3.7939423e-03]
# p2 probs:
# [9.9160111e-01 5.6857284e-04 1.3284909e-03 2.3935572e-03 3.1437670e-04
#  3.7939427e-03]
# p2 hole cards:
# ['DJ', 'S7']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 197}}]
# "p2" declared "fold:0"
# "['p1']" won the round 3 (stack = {'p1': 203.25, 'p2': 196})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663187, 'raise': 131173}
# Started the round 4
# Street "preflop" started. (community card = [])
# 369
# [0.18688172 0.13423558 0.21246646 0.15475138 0.1590724  0.15259245]
# p1 probs:
# [0.18688172 0.13423558 0.21246646 0.15475138 0.1590724  0.15259245]
# p1 hole cards:
# ['CK', 'CA']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 203.25}}]
# "p1" declared "raise:6"
# [9.9921286e-01 3.5013636e-05 1.1030130e-04 2.3535745e-04 1.3094363e-05
#  3.9336830e-04]
# p2 probs:
# [9.9921286e-01 3.5013636e-05 1.1030130e-04 2.3535745e-04 1.3094363e-05
#  3.9336830e-04]
# p2 hole cards:
# ['C9', 'HT']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 6}, {'action': 'raise', 'amount': {'min': 10, 'max': 196}}]
# "p2" declared "fold:0"
# "['p1']" won the round 4 (stack = {'p1': 205.25, 'p2': 194})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625, 0.00875, 0.0075, 0.01, 0.01, 0.00625, 0.01]
# p1 actions map:
# {'call': 78203, 'fold': 87955, 'raise': 376709}
# TOTALNETGAIN p1:
# 3963.329536139301
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663188, 'raise': 131173}
# Started the round 5
# Street "preflop" started. (community card = [])
# [9.9033815e-01 7.6792302e-04 1.5883324e-03 2.9186013e-03 3.8202622e-04
#  4.0048435e-03]
# p2 probs:
# [9.9033827e-01 7.6792313e-04 1.5883326e-03 2.9186015e-03 3.8202628e-04
#  4.0048440e-03]
# p2 hole cards:
# ['CA', 'CJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 194}}]
# "p2" declared "fold:0"
# "['p1']" won the round 5 (stack = {'p1': 206.25, 'p2': 193})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663189, 'raise': 131173}
# Started the round 6
# Street "preflop" started. (community card = [])
# 369
# [0.18345173 0.12099377 0.2501499  0.1412848  0.16313107 0.14098881]
# p1 probs:
# [0.18345173 0.12099377 0.2501499  0.1412848  0.16313107 0.14098881]
# p1 hole cards:
# ['H3', 'DJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 206.25}}]
# "p1" declared "call:2"
# [9.9790490e-01 1.1320054e-04 2.9005713e-04 6.1779295e-04 4.6261062e-05
#  1.0278344e-03]
# p2 probs:
# [9.9790490e-01 1.1320054e-04 2.9005713e-04 6.1779295e-04 4.6261062e-05
#  1.0278344e-03]
# p2 hole cards:
# ['SK', 'D4']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 193}}]
# "p2" declared "fold:0"
# "['p1']" won the round 6 (stack = {'p1': 208.25, 'p2': 191})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625, 0.00875, 0.0075, 0.01, 0.01, 0.00625, 0.01, 0.01]
# p1 actions map:
# {'call': 78204, 'fold': 87955, 'raise': 376709}
# TOTALNETGAIN p1:
# 3963.3395361393013
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40563, 'fold': 663190, 'raise': 131173}
# Started the round 7
# Street "preflop" started. (community card = [])
# [9.8644477e-01 1.0795922e-03 2.0944274e-03 4.0911664e-03 6.3525781e-04
#  5.6546684e-03]
# p2 probs:
# [9.8644483e-01 1.0795923e-03 2.0944276e-03 4.0911669e-03 6.3525786e-04
#  5.6546689e-03]
# p2 hole cards:
# ['CT', 'HT']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 191}}]
# "p2" declared "fold:0"
# "['p1']" won the round 7 (stack = {'p1': 209.25, 'p2': 190})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663191, 'raise': 131173}
# Started the round 8
# Street "preflop" started. (community card = [])
# 369
# [0.19762157 0.12345763 0.24383779 0.13816236 0.15350512 0.14341563]
# p1 probs:
# [0.19762157 0.12345763 0.24383779 0.13816236 0.15350512 0.14341563]
# p1 hole cards:
# ['S5', 'CQ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 209.25}}]
# "p1" declared "fold:0"
# "['p2']" won the round 8 (stack = {'p1': 208.25, 'p2': 191})
# p1 rewards:
# [-0.005, 0.01, 0.00625, 0.00625, -0.005, 0.01, 0.01, 0.00625, -0.005, 0.00625, 0.01, 0.01, 0.00875, 0.00875, 0.00625, 0.00875, 0.0075, 0.01, 0.01, 0.00625, 0.01, 0.01, -0.005]
# p1 actions map:
# {'call': 78204, 'fold': 87956, 'raise': 376709}
# TOTALNETGAIN p1:
# 3963.3345361393012
# Started the round 9
# Street "preflop" started. (community card = [])
# [9.9295855e-01 4.9759791e-04 1.2435535e-03 2.0476489e-03 2.4703317e-04
#  3.0055463e-03]
# p2 probs:
# [9.9295861e-01 4.9759797e-04 1.2435536e-03 2.0476491e-03 2.4703320e-04
#  3.0055465e-03]
# p2 hole cards:
# ['C4', 'CJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 191}}]
# "p2" declared "fold:0"
# "['p1']" won the round 9 (stack = {'p1': 209.25, 'p2': 190})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005]
# p2 actions map:
# {'call': 40563, 'fold': 663192, 'raise': 131173}
# Started the round 10
# Street "preflop" started. (community card = [])
# 369
# [0.17207125 0.14651726 0.19900768 0.16663915 0.16128981 0.1544749 ]
# p1 probs:
# [0.17207125 0.14651726 0.19900768 0.16663915 0.16128981 0.1544749 ]
# p1 hole cards:
# ['DT', 'H3']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 209.25}}]
# "p1" declared "call:2"
# [9.9959153e-01 1.5608470e-05 5.2173265e-05 1.2171310e-04 5.3912108e-06
#  2.1370137e-04]
# p2 probs:
# [9.99591410e-01 1.56084679e-05 5.21732582e-05 1.21713085e-04
#  5.39121038e-06 2.13701336e-04]
# p2 hole cards:
# ['H7', 'D7']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 190}}]
# "p2" declared "fold:0"
# "['p1']" won the round 10 (stack = {'p1': 211.25, 'p2': 188})
# p1 rewards:
# ...
# Started the round 37
# Street "preflop" started. (community card = [])
# [9.9130988e-01 6.2977750e-04 1.2726490e-03 2.4783656e-03 3.0900343e-04
#  4.0004188e-03]
# p2 probs:
# [9.9130976e-01 6.2977744e-04 1.2726489e-03 2.4783653e-03 3.0900340e-04
#  4.0004184e-03]
# p2 hole cards:
# ['DA', 'S8']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 155}}]
# "p2" declared "fold:0"
# "['p1']" won the round 37 (stack = {'p1': 242.25, 'p2': 154})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40564, 'fold': 663352, 'raise': 131173}
# Started the round 38
# Street "preflop" started. (community card = [])
# 369
# [0.18875904 0.1421615  0.2154103  0.14959545 0.15220305 0.15187073]
# p1 probs:
# [0.18875901 0.14216149 0.21541028 0.14959544 0.15220304 0.15187071]
# p1 hole cards:
# ['D9', 'SJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 242.25}}]
# "p1" declared "call:2"
# [9.9872428e-01 6.3350562e-05 1.8777045e-04 3.7537978e-04 2.1840942e-05
#  6.2747003e-04]
# p2 probs:
# [9.9872416e-01 6.3350555e-05 1.8777042e-04 3.7537972e-04 2.1840940e-05
#  6.2746997e-04]
# p2 hole cards:
# ['D5', 'ST']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 154}}]
# "p2" declared "fold:0"
# "['p1']" won the round 38 (stack = {'p1': 244.25, 'p2': 152})
# p1 rewards:
# [-0.005, 0.01, 0.0075, -0.005, 0.0075, 0.0075, 0.01, 0.00875, 0.01, 0.01, 0.00625, 0.0075, -0.005, 0.00875, 0.00875, 0.01]
# p1 actions map:
# {'call': 78213, 'fold': 87974, 'raise': 376773}
# TOTALNETGAIN p1:
# 3963.852036139305
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40564, 'fold': 663353, 'raise': 131173}
# Started the round 39
# Street "preflop" started. (community card = [])
# [9.8148006e-01 1.5678876e-03 2.9888209e-03 5.3278720e-03 9.0706762e-04
#  7.7282107e-03]
# p2 probs:
# [9.8148012e-01 1.5678877e-03 2.9888211e-03 5.3278725e-03 9.0706768e-04
#  7.7282111e-03]
# p2 hole cards:
# ['D2', 'H9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 152}}]
# "p2" declared "fold:0"
# "['p1']" won the round 39 (stack = {'p1': 245.25, 'p2': 151})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40564, 'fold': 663354, 'raise': 131173}
# Started the round 40
# Street "preflop" started. (community card = [])
# 369
# [0.19351767 0.12021983 0.24872312 0.14130776 0.16417049 0.13206111]
# p1 probs:
# [0.19351767 0.12021983 0.24872312 0.14130776 0.16417049 0.13206111]
# p1 hole cards:
# ['D8', 'D5']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 245.25}}]
# "p1" declared "call:2"
# [9.9952292e-01 1.8277828e-05 5.7564139e-05 1.3736114e-04 6.2684599e-06
#  2.5765045e-04]
# p2 probs:
# [9.9952281e-01 1.8277826e-05 5.7564132e-05 1.3736113e-04 6.2684589e-06
#  2.5765042e-04]
# p2 hole cards:
# ['HA', 'S9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 151}}]
# "p2" declared "fold:0"
# "['p1']" won the round 40 (stack = {'p1': 247.25, 'p2': 149})
# p1 rewards:
# [-0.005, 0.01, 0.0075, -0.005, 0.0075, 0.0075, 0.01, 0.00875, 0.01, 0.01, 0.00625, 0.0075, -0.005, 0.00875, 0.00875, 0.01, 0.01]
# p1 actions map:
# {'call': 78214, 'fold': 87974, 'raise': 376773}
# TOTALNETGAIN p1:
# 3963.862036139305
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40564, 'fold': 663355, 'raise': 131173}
# Started the round 41
# Street "preflop" started. (community card = [])
# [9.9262744e-01 5.2263134e-04 1.1744293e-03 2.1437488e-03 2.5583635e-04
#  3.2758422e-03]
# p2 probs:
# [9.9262750e-01 5.2263140e-04 1.1744294e-03 2.1437490e-03 2.5583638e-04
#  3.2758424e-03]
# p2 hole cards:
# ['C9', 'D6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 149}}]
# "p2" declared "fold:0"
# "['p1']" won the round 41 (stack = {'p1': 248.25, 'p2': 148})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40564, 'fold': 663356, 'raise': 131173}
# Started the round 42
# Street "preflop" started. (community card = [])
# 369
# [0.19431637 0.11012007 0.27157503 0.1302294  0.15219921 0.14155997]
# p1 probs:
# [0.19431634 0.11012005 0.271575   0.13022938 0.1521992  0.14155996]
# p1 hole cards:
# ['S5', 'H2']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 248.25}}]
# "p1" declared "raise:3.75"
# [9.9933052e-01 3.1479591e-05 9.2125076e-05 2.0839398e-04 1.0191954e-05
#  3.2741480e-04]
# p2 probs:
# [9.9933040e-01 3.1479587e-05 9.2125061e-05 2.0839395e-04 1.0191953e-05
#  3.2741477e-04]
# p2 hole cards:
# ['ST', 'C6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 3.75}, {'action': 'raise', 'amount': {'min': 5.5, 'max': 148}}]
# "p2" declared "fold:0"
# "['p1']" won the round 42 (stack = {'p1': 249.5, 'p2': 146})
# p1 rewards:
# [-0.005, 0.01, 0.0075, -0.005, 0.0075, 0.0075, 0.01, 0.00875, 0.01, 0.01, 0.00625, 0.0075, -0.005, 0.00875, 0.00875, 0.01, 0.01, 0.00625]
# p1 actions map:
# {'call': 78214, 'fold': 87974, 'raise': 376774}
# TOTALNETGAIN p1:
# 3963.868286139305
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40564, 'fold': 663357, 'raise': 131173}
# Started the round 43
# Street "preflop" started. (community card = [])
# [9.9294043e-01 4.2981526e-04 1.1475658e-03 1.8484071e-03 2.3766146e-04
#  3.3961392e-03]
# p2 probs:
# [9.9294043e-01 4.2981526e-04 1.1475658e-03 1.8484071e-03 2.3766146e-04
#  3.3961392e-03]
# p2 hole cards:
# ['S7', 'H6']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 146}}]
# "p2" declared "fold:0"
# "['p1']" won the round 43 (stack = {'p1': 250.5, 'p2': 145})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40564, 'fold': 663358, 'raise': 131173}
# Started the round 44
# Street "preflop" started. (community card = [])
# 369
# [0.18553932 0.12052814 0.23525377 0.14800508 0.16462745 0.1460463 ]
# p1 probs:
# [0.18553932 0.12052814 0.23525377 0.14800508 0.16462745 0.1460463 ]
# p1 hole cards:
# ['DT', 'HK']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 250.5}}]
# "p1" declared "raise:6"
# [9.9897587e-01 4.5034147e-05 1.4013167e-04 2.7963260e-04 1.7704178e-05
#  5.4155465e-04]
# p2 probs:
# [9.9897593e-01 4.5034150e-05 1.4013168e-04 2.7963263e-04 1.7704180e-05
#  5.4155471e-04]
# p2 hole cards:
# ['H4', 'HJ']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 6}, {'action': 'raise', 'amount': {'min': 10, 'max': 145}}]
# "p2" declared "fold:0"
# "['p1']" won the round 44 (stack = {'p1': 252.5, 'p2': 143})
# p1 rewards:
# [-0.005, 0.01, 0.0075, -0.005, 0.0075, 0.0075, 0.01, 0.00875, 0.01, 0.01, 0.00625, 0.0075, -0.005, 0.00875, 0.00875, 0.01, 0.01, 0.00625, 0.01]
# p1 actions map:
# {'call': 78214, 'fold': 87974, 'raise': 376775}
# TOTALNETGAIN p1:
# 3963.878286139305
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40564, 'fold': 663359, 'raise': 131173}
# Started the round 45
# Street "preflop" started. (community card = [])
# [9.9514920e-01 3.2016792e-04 7.3008123e-04 1.4431883e-03 1.4753400e-04
#  2.2098781e-03]
# p2 probs:
# [9.9514908e-01 3.2016789e-04 7.3008117e-04 1.4431882e-03 1.4753398e-04
#  2.2098778e-03]
# p2 hole cards:
# ['HJ', 'S9']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 143}}]
# "p2" declared "fold:0"
# "['p1']" won the round 45 (stack = {'p1': 253.5, 'p2': 142})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40564, 'fold': 663360, 'raise': 131173}
# Started the round 46
# Street "preflop" started. (community card = [])
# 369
# [0.17766915 0.14856988 0.21467265 0.14203198 0.14491385 0.17214249]
# p1 probs:
# [0.17766915 0.14856988 0.21467265 0.14203198 0.14491385 0.17214249]
# p1 hole cards:
# ['SA', 'H5']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 253.5}}]
# "p1" declared "raise:3.75"
# [9.99130070e-01 3.65132619e-05 1.18879201e-04 2.40779176e-04
#  1.30865365e-05 4.60573181e-04]
# p2 probs:
# [9.9913013e-01 3.6513266e-05 1.1887921e-04 2.4077919e-04 1.3086537e-05
#  4.6057321e-04]
# p2 hole cards:
# ['H2', 'H8']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 3.75}, {'action': 'raise', 'amount': {'min': 5.5, 'max': 142}}]
# "p2" declared "fold:0"
# "['p1']" won the round 46 (stack = {'p1': 254.75, 'p2': 140})
# p1 rewards:
# [-0.005, 0.01, 0.0075, -0.005, 0.0075, 0.0075, 0.01, 0.00875, 0.01, 0.01, 0.00625, 0.0075, -0.005, 0.00875, 0.00875, 0.01, 0.01, 0.00625, 0.01, 0.00625]
# p1 actions map:
# {'call': 78214, 'fold': 87974, 'raise': 376776}
# TOTALNETGAIN p1:
# 3963.884536139305
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40564, 'fold': 663361, 'raise': 131173}
# Started the round 47
# Street "preflop" started. (community card = [])
# [9.8806530e-01 9.1051747e-04 2.0008436e-03 3.3156774e-03 4.6685740e-04
#  5.2408157e-03]
# p2 probs:
# [9.8806518e-01 9.1051735e-04 2.0008434e-03 3.3156769e-03 4.6685734e-04
#  5.2408152e-03]
# p2 hole cards:
# ['H6', 'H7']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 140}}]
# "p2" declared "fold:0"
# "['p1']" won the round 47 (stack = {'p1': 255.75, 'p2': 139})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40564, 'fold': 663362, 'raise': 131173}
# Started the round 48
# Street "preflop" started. (community card = [])
# 369
# [0.19260406 0.10906318 0.2782855  0.13868177 0.1473775  0.13398801]
# p1 probs:
# [0.19260406 0.10906318 0.2782855  0.13868177 0.1473775  0.13398801]
# p1 hole cards:
# ['ST', 'C5']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 255.75}}]
# "p1" declared "raise:5.25"
# [9.9620491e-01 2.5174470e-04 6.1324140e-04 1.1620192e-03 1.0225579e-04
#  1.6658584e-03]
# p2 probs:
# [9.9620491e-01 2.5174470e-04 6.1324140e-04 1.1620192e-03 1.0225579e-04
#  1.6658584e-03]
# p2 hole cards:
# ['SA', 'S7']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 5.25}, {'action': 'raise', 'amount': {'min': 8.5, 'max': 139}}]
# "p2" declared "fold:0"
# "['p1']" won the round 48 (stack = {'p1': 257.5, 'p2': 137})
# p1 rewards:
# [-0.005, 0.01, 0.0075, -0.005, 0.0075, 0.0075, 0.01, 0.00875, 0.01, 0.01, 0.00625, 0.0075, -0.005, 0.00875, 0.00875, 0.01, 0.01, 0.00625, 0.01, 0.00625, 0.00875]
# p1 actions map:
# {'call': 78214, 'fold': 87974, 'raise': 376777}
# TOTALNETGAIN p1:
# 3963.893286139305
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01]
# p2 actions map:
# {'call': 40564, 'fold': 663363, 'raise': 131173}
# Started the round 49
# Street "preflop" started. (community card = [])
# [9.9091327e-01 6.4901658e-04 1.4869340e-03 2.6413833e-03 3.4792171e-04
#  3.9614742e-03]
# p2 probs:
# [9.9091327e-01 6.4901658e-04 1.4869340e-03 2.6413833e-03 3.4792171e-04
#  3.9614742e-03]
# p2 hole cards:
# ['HQ', 'D2']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 137}}]
# "p2" declared "fold:0"
# "['p1']" won the round 49 (stack = {'p1': 258.5, 'p2': 136})
# p2 reward:
# [-0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005, -0.01, -0.005]
# p2 actions map:
# {'call': 40564, 'fold': 663364, 'raise': 131173}
# Started the round 50
# Street "preflop" started. (community card = [])
# 369
# [0.1880032  0.13812813 0.22771893 0.13803989 0.14429377 0.16381606]
# p1 probs:
# [0.1880032  0.13812813 0.22771893 0.13803989 0.14429377 0.16381606]
# p1 hole cards:
# ['S8', 'HT']
# [{'action': 'fold', 'amount': 0}, {'action': 'call', 'amount': 2}, {'action': 'raise', 'amount': {'min': 3, 'max': 258.5}}]
# "p1" declared "fold:0"
# "['p2']" won the round 50 (stack = {'p1': 257.5, 'p2': 137})
# p1 rewards:
# [-0.005, 0.01, 0.0075, -0.005, 0.0075, 0.0075, 0.01, 0.00875, 0.01, 0.01, 0.00625, 0.0075, -0.005, 0.00875, 0.00875, 0.01, 0.01, 0.00625, 0.01, 0.00625, 0.00875, -0.005]
# p1 actions map:
# {'call': 78214, 'fold': 87975, 'raise': 376777}
# TOTALNETGAIN p1:
# 3963.888286139305
# ROUND : 24999
